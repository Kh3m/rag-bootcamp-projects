# %% [markdown]
# ### LangChain Expression Language

# %%
from langchain_core.runnables import RunnableLambda

# %%
chain = (
    RunnableLambda(lambda x : x)
    | RunnableLambda(lambda x: (len(x), 8))
    | RunnableLambda(lambda x: max(x[0], x[1]))
)

# %%
chain.invoke("Love Me Please")
# Out:
# 14
